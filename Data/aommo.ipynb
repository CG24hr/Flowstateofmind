# %% [markdown]
# # IMPORT TOOLS

# %%
# BASIC TOOLS
import numpy as np
import pandas as pd
import datetime as dt

# STATISTIC TOOLS
import matplotlib.pyplot as plt 
import seaborn as sns
import scipy.stats as stats
import pingouin as pg 
import statsmodels.formula.api as smf
from statsmodels.tools.tools import add_constant
from scipy.optimize import linear_sum_assignment
from lifelines import KaplanMeierFitter, NelsonAalenFitter, CoxPHFitter

# PRE - PROCESSING TOOLS 
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, PowerTransformer, LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# SUPERVISED LEARNING TOOLS
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV
from sklearn.linear_model import LinearRegression, LogisticRegression, Lasso, Ridge
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC 
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier, BaggingClassifier, RandomForestClassifier, RandomForestRegressor, AdaBoostClassifier, AdaBoostRegressor, GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, accuracy_score, confusion_matrix, classification_report, roc_curve, roc_auc_score, pairwise_distances

# UNSUPERVISED LEARNING TOOLS
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from sklearn.manifold import TSNE 
from sklearn.decomposition import PCA, NMF

# DEEP LEARNING TOOLS 
from sklearn.neural_network import MLPRegressor, MLPClassifier

# %% [markdown]
# # IMPORT DATA

# %%
xls = pd.ExcelFile('D:\\Users\\Desktop\\Python code\\GitHub\\Flowstateofmind\\Data\\csv\\Final_aommo.xlsx')
print(xls.sheet_names)
# Out:
# ['yes (2)', 'Summary']

# %%
df = xls.parse(0)
sample = df.iloc[:, 3:]
sample
# Out:
#     Sex  Age  Level  EBL  Total  op time  Spinopelvic_preop_SVA  \
# 0     2   63      3  259    139       83                  45.97
# 1     1   69      4  270    133      102                 -10.10
# 2     2   56      3  318     62       95                  24.61
# 3     2   59      2  224    191       70                  31.22
# 4     2   52      3  200    165      109                  75.13
# 5     2   70      3  293    114       78                  25.61
# 6     1   60      4  193     64      105                  50.20
# 7     2   64      3  208    176       84                 100.00
# 8     1   65      3  220     74       74                  30.94
# 9     2   57      4  259    109      102                  17.60
# 10    2   56      3  214    190       75                  71.49
# 11    2   74      4  193     59       99                  27.46
# 12    2   61      3  174     56       77                  96.22
# 13    2   68      4  202    179       89                  22.01
# 14    1   62      3  157    182       73                  18.22
# 15    2   77      4  237    126       65                  75.49
# 16    1   58      3  251    167       92                  88.71
# 17    1   70      2  202     70      101                  48.12
# 18    2   61      2  325    128       85                  42.53
# 19    2   61      3  295    106       70                  54.74
# 20    2   64      3  336     59       65                  57.14
# 21    1   65      4  322    143       85                  19.34
# 22    1   47      4  190     97       93                  29.11
# 23    2   67      3  254    104      110                  27.09
# 24    2   59      2  286    102       74                  31.22
# 25    2   52      3  166    199       73                  75.13
# 26    1   70      3  287    188       71                  25.61
# 27    2   60      4  209    188       73                  50.20
# 28    1   64      3  164    169       72                 100.00
# 29    2   65      3  188    142      107                  30.94
# 30    1   57      4  190    172       92                  17.60
# 31    1   56      3  323    157       74                  71.49
# 32    1   74      4  169    129       91                  27.46
# 33    2   58      3  310    115       83                  88.71
# 34    1   70      2  183    113       71                  48.12
# 35    1   61      2  322    115       97                  42.53
# 36    2   61      3  254    150      105                  54.74
# 37    2   64      3  164     83       73                  57.14
# 38    1   65      4  323     62      108                  19.34
# 39    2   47      4  199    134       83                  29.11
# 40    2   67      3  280     72       61                  27.09
# 41    2   61      2  258    183       71                  42.53
#
#     Spinopelvic_preop_PI  Spinopelvic_preop_LL  Spinopelvic_preop_PT  ...  \
# 0                  60.20                 24.60                 38.80  ...
# 1                  60.64                 32.30                 24.50  ...
# 2                  70.49                 27.20                 39.66  ...
# 3                  54.44                 20.36                 47.57  ...
# 4                  56.24                 35.70                 28.72  ...
# 5                  63.50                 22.65                 40.76  ...
# 6                  54.66                 34.22                 29.86  ...
# 7                  55.62                 31.40                 30.60  ...
# 8                  57.38                 41.90                 23.98  ...
# 9                  55.00                 35.02                 30.36  ...
# 10                 41.19                 31.73                 13.07  ...
# 11                 59.08                 24.88                 28.61  ...
# 12                 42.27                  9.25                 23.72  ...
# 13                 58.17                 38.07                 26.52  ...
# 14                 49.78                 39.08                 10.76  ...
# 15                 43.26                 23.32                 28.21  ...
# 16                 54.15                  8.37                 26.76  ...
# 17                 47.45                 35.64                 15.19  ...
# 18                 59.36                 38.46                 20.43  ...
# 19                 49.15                 33.93                 29.18  ...
# 20                 59.33                 48.58                 26.27  ...
# 21                 50.09                 45.75                 18.56  ...
# 22                 45.26                 34.28                 19.75  ...
# 23                 48.22                 23.22                 24.96  ...
# 24                 54.44                 20.36                 47.57  ...
# 25                 56.24                 35.70                 28.72  ...
# 26                 63.50                 22.65                 40.76  ...
# 27                 54.66                 34.22                 29.86  ...
# 28                 55.62                 31.40                 30.60  ...
# 29                 57.38                 41.90                 23.98  ...
# 30                 55.00                 35.02                 30.36  ...
# 31                 41.19                 31.73                 13.07  ...
# 32                 59.08                 24.88                 28.61  ...
# 33                 54.15                  8.37                 26.76  ...
# 34                 47.45                 35.64                 15.19  ...
# 35                 59.36                 38.46                 20.43  ...
# 36                 49.15                 33.93                 29.18  ...
# 37                 59.33                 48.58                 26.27  ...
# 38                 50.09                 45.75                 18.56  ...
# 39                 45.26                 34.28                 19.75  ...
# 40                 48.22                 23.22                 24.96  ...
# 41                 59.36                 38.46                 20.43  ...
#
#     VAS_3mo  VAS_6mo  VAS_12mo  VAS_24mo  ODI_preop  ODI_1mo  ODI_3mo  \
# 0         6        4         3         5       0.88     0.80     0.72
# 1         8        6         2         3       0.84     0.78     0.78
# 2         8        6         4         3       0.74     0.80     0.74
# 3         7        6         5         3       0.80     0.80     0.78
# 4         7        6         5         5       0.74     0.84     0.78
# 5         6        6         4         5       0.80     0.82     0.72
# 6         7        4         5         5       0.76     0.84     0.82
# 7         7        3         2         4       0.80     0.84     0.78
# 8         6        5         2         5       0.82     0.78     0.74
# 9         6        6         5         2       0.84     0.72     0.70
# 10        6        3         2         2       0.82     0.74     0.84
# 11        8        4         2         3       0.84     0.80     0.82
# 12        8        4         4         3       0.80     0.80     0.84
# 13        6        3         2         2       0.80     0.74     0.84
# 14        6        5         3         4       0.82     0.86     0.78
# 15        8        5         2         5       0.80     0.80     0.78
# 16        7        5         3         2       0.82     0.80     0.80
# 17        8        6         3         2       0.84     0.84     0.80
# 18        6        3         4         2       0.82     0.90     0.78
# 19        8        5         3         3       0.80     0.72     0.78
# 20        6        6         3         2       0.68     0.78     0.84
# 21        6        5         4         4       0.84     0.68     0.78
# 22        6        5         3         3       0.84     0.84     0.86
# 23        6        6         2         4       0.84     0.84     0.78
# 24        6        5         2         2       0.68     0.84     0.88
# 25        7        4         3         4       0.80     0.72     0.82
# 26        8        3         5         4       0.76     0.72     0.88
# 27        6        4         2         4       0.86     0.82     0.92
# 28        6        4         3         3       0.84     0.78     0.74
# 29        8        5         5         2       0.78     0.84     0.70
# 30        6        6         2         5       0.80     0.86     0.76
# 31        6        4         3         5       0.86     0.84     0.76
# 32        6        6         5         5       0.84     0.86     0.86
# 33        6        5         3         3       0.82     0.92     0.82
# 34        8        3         5         4       0.78     0.74     0.72
# 35        8        4         3         3       0.80     0.82     0.72
# 36        7        6         2         2       0.86     0.80     0.76
# 37        8        6         2         2       0.76     0.82     0.80
# 38        7        4         3         2       0.76     0.90     0.78
# 39        8        6         2         3       0.88     0.80     0.80
# 40        7        5         5         4       0.92     0.82     0.80
# 41        8        4         5         2       0.80     0.86     0.76
#
#     ODI_6mo  ODI_12mo  ODI_24mo
# 0      0.60      0.38      0.40
# 1      0.58      0.40      0.38
# 2      0.56      0.44      0.30
# 3      0.54      0.40      0.48
# 4      0.58      0.40      0.34
# 5      0.54      0.42      0.34
# 6      0.62      0.48      0.38
# 7      0.62      0.48      0.46
# 8      0.66      0.42      0.26
# 9      0.66      0.32      0.42
# 10     0.62      0.42      0.34
# 11     0.60      0.28      0.42
# 12     0.48      0.44      0.46
# 13     0.60      0.46      0.30
# 14     0.66      0.38      0.44
# 15     0.52      0.44      0.34
# 16     0.54      0.36      0.38
# 17     0.64      0.34      0.30
# 18     0.50      0.36      0.44
# 19     0.56      0.48      0.40
# 20     0.66      0.42      0.48
# 21     0.62      0.40      0.36
# 22     0.62      0.36      0.34
# 23     0.58      0.40      0.30
# 24     0.64      0.40      0.44
# 25     0.60      0.38      0.50
# 26     0.72      0.44      0.42
# 27     0.64      0.42      0.32
# 28     0.68      0.42      0.42
# 29     0.52      0.48      0.48
# 30     0.60      0.42      0.38
# 31     0.64      0.30      0.36
# 32     0.54      0.42      0.40
# 33     0.56      0.36      0.42
# 34     0.60      0.40      0.50
# 35     0.60      0.42      0.46
# 36     0.50      0.40      0.40
# 37     0.52      0.30      0.36
# 38     0.60      0.36      0.44
# 39     0.66      0.44      0.50
# 40     0.60      0.40      0.50
# 41     0.58      0.46      0.42
#
# [42 rows x 54 columns]

# %% [markdown]
# # UNDERSTAND THE DATA

# %%
sample.isna().sum()
# Out:
# Sex                      0
# Age                      0
# Level                    0
# EBL                      0
# Total                    0
# op time                  0
# Spinopelvic_preop_SVA    0
# Spinopelvic_preop_PI     0
# Spinopelvic_preop_LL     0
# Spinopelvic_preop_PT     0
# Spinopelvic_preop_SS     0
# Spinopelvic_1mo_SVA      0
# Spinopelvic_1mo_PI       0
# Spinopelvic_1mo_LL       0
# Spinopelvic_1mo_PT       0
# Spinopelvic_1mo_SS       0
# Spinopelvic_3mo_SVA      0
# Spinopelvic_3mo_PI       0
# Spinopelvic_3mo_LL       0
# Spinopelvic_3mo_PT       0
# Spinopelvic_3mo_SS       0
# Spinopelvic_6mo_SVA      0
# Spinopelvic_6mo_PI       0
# Spinopelvic_6mo_LL       0
# Spinopelvic_6mo_PT       0
# Spinopelvic_6mo_SS       0
# Spinopelvic_12mo_SVA     0
# Spinopelvic_12mo_PI      0
# Spinopelvic_12mo_LL      0
# Spinopelvic_12mo_PT      0
# Spinopelvic_12mo_SS      0
# Spinopelvic_24mo_SVA     0
# Spinopelvic_24mo_PI      0
# Spinopelvic_24mo_LL      0
# Spinopelvic_24mo_PT      0
# Spinopelvic_24mo_SS      0
# EQ-5D-5L_preop           0
# EQ-5D-5L_1mo             0
# EQ-5D-5L_3mo             0
# EQ-5D-5L_6mo             0
# EQ-5D-5L_12mo            0
# EQ-5D-5L_24mo            0
# VAS_preop                0
# VAS_1mo                  0
# VAS_3mo                  0
# VAS_6mo                  0
# VAS_12mo                 0
# VAS_24mo                 0
# ODI_preop                0
# ODI_1mo                  0
# ODI_3mo                  0
# ODI_6mo                  0
# ODI_12mo                 0
# ODI_24mo                 0
# dtype: int64

# %%
print(sample.info())
sample.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 54 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sex                    42 non-null     int64
#  1   Age                    42 non-null     int64
#  2   Level                  42 non-null     int64
#  3   EBL                    42 non-null     int64
#  4   Total                  42 non-null     int64
#  5   op time                42 non-null     int64
#  6   Spinopelvic_preop_SVA  42 non-null     float64
#  7   Spinopelvic_preop_PI   42 non-null     float64
#  8   Spinopelvic_preop_LL   42 non-null     float64
#  9   Spinopelvic_preop_PT   42 non-null     float64
#  10  Spinopelvic_preop_SS   42 non-null     float64
#  11  Spinopelvic_1mo_SVA    42 non-null     float64
#  12  Spinopelvic_1mo_PI     42 non-null     float64
#  13  Spinopelvic_1mo_LL     42 non-null     float64
#  14  Spinopelvic_1mo_PT     42 non-null     float64
#  15  Spinopelvic_1mo_SS     42 non-null     float64
#  16  Spinopelvic_3mo_SVA    42 non-null     float64
#  17  Spinopelvic_3mo_PI     42 non-null     float64
#  18  Spinopelvic_3mo_LL     42 non-null     float64
#  19  Spinopelvic_3mo_PT     42 non-null     float64
#  20  Spinopelvic_3mo_SS     42 non-null     float64
#  21  Spinopelvic_6mo_SVA    42 non-null     float64
#  22  Spinopelvic_6mo_PI     42 non-null     float64
#  23  Spinopelvic_6mo_LL     42 non-null     float64
#  24  Spinopelvic_6mo_PT     42 non-null     float64
#  25  Spinopelvic_6mo_SS     42 non-null     float64
#  26  Spinopelvic_12mo_SVA   42 non-null     float64
#  27  Spinopelvic_12mo_PI    42 non-null     float64
#  28  Spinopelvic_12mo_LL    42 non-null     float64
#  29  Spinopelvic_12mo_PT    42 non-null     float64
#  30  Spinopelvic_12mo_SS    42 non-null     float64
#  31  Spinopelvic_24mo_SVA   42 non-null     float64
#  32  Spinopelvic_24mo_PI    42 non-null     float64
#  33  Spinopelvic_24mo_LL    42 non-null     float64
#  34  Spinopelvic_24mo_PT    42 non-null     float64
#  35  Spinopelvic_24mo_SS    42 non-null     float64
#  36  EQ-5D-5L_preop         42 non-null     float64
#  37  EQ-5D-5L_1mo           42 non-null     float64
#  38  EQ-5D-5L_3mo           42 non-null     float64
#  39  EQ-5D-5L_6mo           42 non-null     float64
#  40  EQ-5D-5L_12mo          42 non-null     float64
#  41  EQ-5D-5L_24mo          42 non-null     float64
#  42  VAS_preop              42 non-null     int64
#  43  VAS_1mo                42 non-null     int64
#  44  VAS_3mo                42 non-null     int64
#  45  VAS_6mo                42 non-null     int64
#  46  VAS_12mo               42 non-null     int64
#  47  VAS_24mo               42 non-null     int64
#  48  ODI_preop              42 non-null     float64
#  49  ODI_1mo                42 non-null     float64
#  50  ODI_3mo                42 non-null     float64
#  51  ODI_6mo                42 non-null     float64
#  52  ODI_12mo               42 non-null     float64
#  53  ODI_24mo               42 non-null     float64
# dtypes: float64(42), int64(12)
# memory usage: 17.8 KB
# None
# Index(['Sex', 'Age', 'Level', 'EBL', 'Total', 'op time',
#        'Spinopelvic_preop_SVA', 'Spinopelvic_preop_PI', 'Spinopelvic_preop_LL',
#        'Spinopelvic_preop_PT', 'Spinopelvic_preop_SS', 'Spinopelvic_1mo_SVA',
#        'Spinopelvic_1mo_PI', 'Spinopelvic_1mo_LL', 'Spinopelvic_1mo_PT',
#        'Spinopelvic_1mo_SS', 'Spinopelvic_3mo_SVA', 'Spinopelvic_3mo_PI',
#        'Spinopelvic_3mo_LL', 'Spinopelvic_3mo_PT', 'Spinopelvic_3mo_SS',
#        'Spinopelvic_6mo_SVA', 'Spinopelvic_6mo_PI', 'Spinopelvic_6mo_LL',
#        'Spinopelvic_6mo_PT', 'Spinopelvic_6mo_SS', 'Spinopelvic_12mo_SVA',
#        'Spinopelvic_12mo_PI', 'Spinopelvic_12mo_LL', 'Spinopelvic_12mo_PT',
#        'Spinopelvic_12mo_SS', 'Spinopelvic_24mo_SVA', 'Spinopelvic_24mo_PI',
#        'Spinopelvic_24mo_LL', 'Spinopelvic_24mo_PT', 'Spinopelvic_24mo_SS',
#        'EQ-5D-5L_preop', 'EQ-5D-5L_1mo', 'EQ-5D-5L_3mo', 'EQ-5D-5L_6mo',
#        'EQ-5D-5L_12mo', 'EQ-5D-5L_24mo', 'VAS_preop', 'VAS_1mo', 'VAS_3mo',
#        'VAS_6mo', 'VAS_12mo', 'VAS_24mo', 'ODI_preop', 'ODI_1mo', 'ODI_3mo',
#        'ODI_6mo', 'ODI_12mo', 'ODI_24mo'],
#       dtype='object')

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ## Baseline Characteristics

# %%
sample['Sex'].value_counts()
# Out:
# 2    26
# 1    16
# Name: Sex, dtype: int64

# %%
# Test for normality
baseline = sample[['Age','Level','EBL','Total','op time']]
for i in baseline.columns : 
    print(i, stats.shapiro(df[i]))
# Out:
# Age ShapiroResult(statistic=0.9812403917312622, pvalue=0.7094213962554932)
# Level ShapiroResult(statistic=0.7975444197654724, pvalue=3.9276892493944615e-06)
# EBL ShapiroResult(statistic=0.924625039100647, pvalue=0.008569853380322456)
# Total ShapiroResult(statistic=0.9370397925376892, pvalue=0.022543461993336678)
# op time ShapiroResult(statistic=0.9303672313690186, pvalue=0.013330301269888878)

# %% [markdown]
# For each baseline characteristic
# if p_value > 0.05, use mean
# elif p_value < 0.05, use median (or 50% quartile)

# %%
sample[['Age','Level','EBL','Total','op time']].describe()
# Out:
#              Age      Level         EBL       Total     op time
# count  42.000000  42.000000   42.000000   42.000000   42.000000
# mean   62.309524   3.142857  239.785714  127.761905   84.761905
# std     6.671703   0.683300   55.666049   44.751242   14.183139
# min    47.000000   2.000000  157.000000   56.000000   61.000000
# 25%    58.250000   3.000000  193.000000   98.250000   73.000000
# 50%    61.500000   3.000000  230.500000  128.500000   83.000000
# 75%    66.500000   4.000000  286.750000  168.500000   96.500000
# max    77.000000   4.000000  336.000000  199.000000  110.000000

# %% [markdown]
# ## Spinopelvic one sample comparison

# %%
# test for normality
spinopelvic = sample[['Spinopelvic_preop_SVA', 'Spinopelvic_preop_PI', 'Spinopelvic_preop_LL',
       'Spinopelvic_preop_PT', 'Spinopelvic_preop_SS', 'Spinopelvic_1mo_SVA',
       'Spinopelvic_1mo_PI', 'Spinopelvic_1mo_LL', 'Spinopelvic_1mo_PT',
       'Spinopelvic_1mo_SS', 'Spinopelvic_3mo_SVA', 'Spinopelvic_3mo_PI',
       'Spinopelvic_3mo_LL', 'Spinopelvic_3mo_PT', 'Spinopelvic_3mo_SS',
       'Spinopelvic_6mo_SVA', 'Spinopelvic_6mo_PI', 'Spinopelvic_6mo_LL',
       'Spinopelvic_6mo_PT', 'Spinopelvic_6mo_SS', 'Spinopelvic_12mo_SVA',
       'Spinopelvic_12mo_PI', 'Spinopelvic_12mo_LL', 'Spinopelvic_12mo_PT',
       'Spinopelvic_12mo_SS', 'Spinopelvic_24mo_SVA', 'Spinopelvic_24mo_PI',
       'Spinopelvic_24mo_LL', 'Spinopelvic_24mo_PT', 'Spinopelvic_24mo_SS']]
for i in spinopelvic.columns : 
    print(i, stats.shapiro(df[i]))
# Out:
# Spinopelvic_preop_SVA ShapiroResult(statistic=0.9310577511787415, pvalue=0.014066877774894238)
# Spinopelvic_preop_PI ShapiroResult(statistic=0.9636607766151428, pvalue=0.19938157498836517)
# Spinopelvic_preop_LL ShapiroResult(statistic=0.9422385692596436, pvalue=0.034231625497341156)
# Spinopelvic_preop_PT ShapiroResult(statistic=0.9468523859977722, pvalue=0.04985716566443443)
# Spinopelvic_preop_SS ShapiroResult(statistic=0.9710264205932617, pvalue=0.3572752773761749)
# Spinopelvic_1mo_SVA ShapiroResult(statistic=0.8904237747192383, pvalue=0.0007533872849307954)
# Spinopelvic_1mo_PI ShapiroResult(statistic=0.960454523563385, pvalue=0.15332069993019104)
# Spinopelvic_1mo_LL ShapiroResult(statistic=0.8743226528167725, pvalue=0.000267354364041239)
# Spinopelvic_1mo_PT ShapiroResult(statistic=0.9689175486564636, pvalue=0.30361154675483704)
# Spinopelvic_1mo_SS ShapiroResult(statistic=0.8803831934928894, pvalue=0.000391945504816249)
# Spinopelvic_3mo_SVA ShapiroResult(statistic=0.9754557013511658, pvalue=0.49378255009651184)
# Spinopelvic_3mo_PI ShapiroResult(statistic=0.9648466110229492, pvalue=0.21952147781848907)
# Spinopelvic_3mo_LL ShapiroResult(statistic=0.8987784385681152, pvalue=0.00132360914722085)
# Spinopelvic_3mo_PT ShapiroResult(statistic=0.951468825340271, pvalue=0.07290995121002197)
# Spinopelvic_3mo_SS ShapiroResult(statistic=0.9286191463470459, pvalue=0.011640745215117931)
# Spinopelvic_6mo_SVA ShapiroResult(statistic=0.9568278789520264, pvalue=0.11362216621637344)
# Spinopelvic_6mo_PI ShapiroResult(statistic=0.9535316228866577, pvalue=0.08647553622722626)
# Spinopelvic_6mo_LL ShapiroResult(statistic=0.9625703692436218, pvalue=0.18240612745285034)
# Spinopelvic_6mo_PT ShapiroResult(statistic=0.9683589339256287, pvalue=0.2905994653701782)
# Spinopelvic_6mo_SS ShapiroResult(statistic=0.9112846255302429, pvalue=0.003189457580447197)
# Spinopelvic_12mo_SVA ShapiroResult(statistic=0.939153790473938, pvalue=0.026694754138588905)
# Spinopelvic_12mo_PI ShapiroResult(statistic=0.9564629197120667, pvalue=0.11023925989866257)
# Spinopelvic_12mo_LL ShapiroResult(statistic=0.8838606476783752, pvalue=0.0004900946514680982)
# Spinopelvic_12mo_PT ShapiroResult(statistic=0.9809088110923767, pvalue=0.6966238021850586)
# Spinopelvic_12mo_SS ShapiroResult(statistic=0.8487944602966309, pvalue=5.8330562751507387e-05)
# Spinopelvic_24mo_SVA ShapiroResult(statistic=0.9103352427482605, pvalue=0.00297880289144814)
# Spinopelvic_24mo_PI ShapiroResult(statistic=0.960399866104126, pvalue=0.15263207256793976)
# Spinopelvic_24mo_LL ShapiroResult(statistic=0.8096204996109009, pvalue=7.1474328251497354e-06)
# Spinopelvic_24mo_PT ShapiroResult(statistic=0.9788017868995667, pvalue=0.6155266165733337)
# Spinopelvic_24mo_SS ShapiroResult(statistic=0.9141842126846313, pvalue=0.003936081659048796)

# %%
# Define the time points and parameters to analyze
time_points = ['1mo', '3mo', '6mo', '12mo', '24mo']
parameters = ['SVA', 'PI', 'LL', 'PT', 'SS']

# Loop through each parameter and time point
for param in parameters:
    preop_col = f"Spinopelvic_preop_{param}"  # Preoperative column name
    for tp in time_points:
        followup_col = f"Spinopelvic_{tp}_{param}"  # Follow-up column name
        
        # Calculate the mean difference and its SD
        differences = spinopelvic[preop_col] - spinopelvic[followup_col]
        mean_diff = np.mean(differences)
        sd_diff = np.std(differences, ddof=1)  # Use ddof=1 for sample SD
        
        # Perform the paired t-test
        result = pg.ttest(spinopelvic[preop_col], spinopelvic[followup_col], paired=True, alternative='two-sided')
        
        # Print the result
        print(f"T-test: {param} - Preoperative vs {tp}")
        print(f"Mean Difference: {mean_diff:.2f} ± {sd_diff:.2f}")
        print(result)
        print("\n")
# Out:
# T-test: SVA - Preoperative vs 1mo
# Mean Difference: -0.06 ± 24.13
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -0.015924   41   two-sided  0.987372  [-7.58, 7.46]  0.002722  0.167
#
#            power
# T-test  0.050034
#
#
# T-test: SVA - Preoperative vs 3mo
# Mean Difference: -0.04 ± 25.08
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -0.009411   41   two-sided  0.992537  [-7.85, 7.78]  0.001681  0.167
#
#            power
# T-test  0.050013
#
#
# T-test: SVA - Preoperative vs 6mo
# Mean Difference: -7.33 ± 26.19
#                T  dof alternative     p-val           CI95%   cohen-d   BF10  \
# T-test -1.814817   41   two-sided  0.076873  [-15.49, 0.83]  0.349782  0.746
#
#            power
# T-test  0.600103
#
#
# T-test: SVA - Preoperative vs 12mo
# Mean Difference: 0.19 ± 27.69
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test  0.045354   41   two-sided  0.964045  [-8.44, 8.82]  0.008225  0.167
#
#            power
# T-test  0.050311
#
#
# T-test: SVA - Preoperative vs 24mo
# Mean Difference: 0.83 ± 31.48
#               T  dof alternative     p-val           CI95%   cohen-d   BF10  \
# T-test  0.17046   41   two-sided  0.865487  [-8.98, 10.64]  0.037074  0.169
#
#            power
# T-test  0.056333
#
#
# T-test: PI - Preoperative vs 1mo
# Mean Difference: -0.01 ± 0.63
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -0.139919   41   two-sided  0.889409  [-0.21, 0.18]  0.002063  0.168
#
#           power
# T-test  0.05002
#
#
# T-test: PI - Preoperative vs 3mo
# Mean Difference: -0.25 ± 0.92
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -1.752617   41   two-sided  0.087144  [-0.54, 0.04]  0.038076  0.677
#
#            power
# T-test  0.056682
#
#
# T-test: PI - Preoperative vs 6mo
# Mean Difference: -0.14 ± 0.50
#               T  dof alternative    p-val         CI95%   cohen-d   BF10  \
# T-test -1.84459   41   two-sided  0.07233  [-0.3, 0.01]  0.021924  0.782
#
#            power
# T-test  0.052209
#
#
# T-test: PI - Preoperative vs 12mo
# Mean Difference: -0.13 ± 0.53
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -1.599753   41   two-sided  0.117332  [-0.29, 0.03]  0.020193  0.539
#
#            power
# T-test  0.051874
#
#
# T-test: PI - Preoperative vs 24mo
# Mean Difference: -0.11 ± 0.53
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -1.297709   41   two-sided  0.201641  [-0.27, 0.06]  0.016201  0.364
#
#            power
# T-test  0.051206
#
#
# T-test: LL - Preoperative vs 1mo
# Mean Difference: -3.60 ± 18.64
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -1.251383   41   two-sided  0.217888  [-9.41, 2.21]  0.307636  0.345
#
#            power
# T-test  0.494844
#
#
# T-test: LL - Preoperative vs 3mo
# Mean Difference: -5.74 ± 15.40
#                T  dof alternative     p-val            CI95%   cohen-d   BF10  \
# T-test -2.414448   41   two-sided  0.020307  [-10.54, -0.94]  0.610731  2.199
#
#            power
# T-test  0.971527
#
#
# T-test: LL - Preoperative vs 6mo
# Mean Difference: -6.63 ± 9.31
#               T  dof alternative     p-val           CI95%  cohen-d     BF10  \
# T-test -4.61481   41   two-sided  0.000038  [-9.53, -3.73]  0.62792  576.931
#
#           power
# T-test  0.97791
#
#
# T-test: LL - Preoperative vs 12mo
# Mean Difference: -5.09 ± 13.87
#               T  dof alternative     p-val           CI95%   cohen-d   BF10  \
# T-test -2.37894   41   two-sided  0.022101  [-9.41, -0.77]  0.504925  2.049
#
#            power
# T-test  0.891541
#
#
# T-test: LL - Preoperative vs 24mo
# Mean Difference: -9.49 ± 18.95
#                T  dof alternative     p-val            CI95%   cohen-d  \
# T-test -3.243802   41   two-sided  0.002349  [-15.39, -3.58]  0.765544
#
#           BF10     power
# T-test  14.113  0.998026
#
#
# T-test: PT - Preoperative vs 1mo
# Mean Difference: 2.60 ± 9.38
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test  1.795565   41   two-sided  0.079936  [-0.32, 5.52]  0.268696  0.723
#
#            power
# T-test  0.397788
#
#
# T-test: PT - Preoperative vs 3mo
# Mean Difference: 2.03 ± 9.18
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test  1.430668   41   two-sided  0.160103  [-0.83, 4.89]  0.238424  0.429
#
#            power
# T-test  0.326279
#
#
# T-test: PT - Preoperative vs 6mo
# Mean Difference: 2.28 ± 9.03
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test  1.635337   41   two-sided  0.109634  [-0.54, 5.09]  0.236893  0.568
#
#            power
# T-test  0.322806
#
#
# T-test: PT - Preoperative vs 12mo
# Mean Difference: 2.98 ± 11.90
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test  1.622803   41   two-sided  0.112297  [-0.73, 6.69]  0.319771  0.557
#
#            power
# T-test  0.525439
#
#
# T-test: PT - Preoperative vs 24mo
# Mean Difference: 6.64 ± 10.35
#                T  dof alternative    p-val         CI95%   cohen-d     BF10  \
# T-test  4.156571   41   two-sided  0.00016  [3.41, 9.86]  0.750441  156.399
#
#            power
# T-test  0.997338
#
#
# T-test: SS - Preoperative vs 1mo
# Mean Difference: -1.43 ± 9.90
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -0.933041   41   two-sided  0.356261  [-4.51, 1.66]  0.186033  0.251
#
#            power
# T-test  0.217825
#
#
# T-test: SS - Preoperative vs 3mo
# Mean Difference: -0.54 ± 7.63
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -0.459479   41   two-sided  0.648317  [-2.92, 1.84]  0.091005  0.184
#
#            power
# T-test  0.088802
#
#
# T-test: SS - Preoperative vs 6mo
# Mean Difference: -1.92 ± 8.95
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -1.389344   41   two-sided  0.172228  [-4.71, 0.87]  0.264888  0.407
#
#            power
# T-test  0.388538
#
#
# T-test: SS - Preoperative vs 12mo
# Mean Difference: -2.17 ± 10.36
#                T  dof alternative     p-val         CI95%   cohen-d  BF10  \
# T-test -1.356298   41   two-sided  0.182427  [-5.4, 1.06]  0.289066  0.39
#
#            power
# T-test  0.448151
#
#
# T-test: SS - Preoperative vs 24mo
# Mean Difference: -5.05 ± 12.27
#                T  dof alternative     p-val           CI95%   cohen-d   BF10  \
# T-test -2.668622   41   two-sided  0.010861  [-8.88, -1.23]  0.561001  3.734
#
#            power
# T-test  0.944007

# %% [markdown]
# ## EQ-5D-5L

# %%
EQ = sample[['EQ-5D-5L_preop', 'EQ-5D-5L_1mo', 'EQ-5D-5L_3mo', 'EQ-5D-5L_6mo',
       'EQ-5D-5L_12mo', 'EQ-5D-5L_24mo']]
EQ.head()
# Out:
#    EQ-5D-5L_preop  EQ-5D-5L_1mo  EQ-5D-5L_3mo  EQ-5D-5L_6mo  EQ-5D-5L_12mo  \
# 0          -0.174         0.062         0.228         0.208          0.645
# 1          -0.028         0.106        -0.165         0.301          0.801
# 2          -0.174         0.151         0.199         0.287          0.753
# 3          -0.104         0.004        -0.127         0.127          0.925
# 4          -0.160         0.179         0.104         0.628          0.884
#
#    EQ-5D-5L_24mo
# 0          0.829
# 1          0.879
# 2          0.768
# 3          0.738
# 4          0.814

# %%
time_points = ['1mo', '3mo', '6mo', '12mo', '24mo']


for tp in time_points:
    followup_col = f"EQ-5D-5L_{tp}"  # Follow-up column name
        
    # Calculate the mean difference and its SD
    differences = EQ['EQ-5D-5L_preop'] - EQ[followup_col]
    mean_diff = np.mean(differences)
    sd_diff = np.std(differences, ddof=1)  # Use ddof=1 for sample SD
        
    # Perform the paired t-test
    result = pg.ttest(EQ['EQ-5D-5L_preop'], EQ[followup_col], paired=True, alternative='two-sided')
        
    # Print the result
    print(f"EQ-5D-5L: Preoperative vs {tp}")
    print(f"Mean Difference: {mean_diff:.2f} ± {sd_diff:.2f}")
    print(result)
    print("\n")
# Out:
# EQ-5D-5L: Preoperative vs 1mo
# Mean Difference: -0.05 ± 0.21
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -1.732645   41   two-sided  0.090676  [-0.12, 0.01]  0.366446  0.656
#
#            power
# T-test  0.640204
#
#
# EQ-5D-5L: Preoperative vs 3mo
# Mean Difference: -0.08 ± 0.23
#                T  dof alternative     p-val           CI95%   cohen-d   BF10  \
# T-test -2.244255   41   two-sided  0.030277  [-0.15, -0.01]  0.564005  1.578
#
#            power
# T-test  0.946118
#
#
# EQ-5D-5L: Preoperative vs 6mo
# Mean Difference: -0.26 ± 0.28
#                T  dof alternative         p-val           CI95%   cohen-d  \
# T-test -5.931938   41   two-sided  5.407075e-07  [-0.34, -0.17]  1.556509
#
#            BF10  power
# T-test  3.0e+04    1.0
#
#
# EQ-5D-5L: Preoperative vs 12mo
# Mean Difference: -0.80 ± 0.15
#                 T  dof alternative         p-val           CI95%   cohen-d  \
# T-test -34.235256   41   two-sided  8.760908e-32  [-0.85, -0.75]  6.558118
#
#              BF10  power
# T-test  2.458e+28    1.0
#
#
# EQ-5D-5L: Preoperative vs 24mo
# Mean Difference: -0.80 ± 0.16
#                 T  dof alternative         p-val           CI95%   cohen-d  \
# T-test -31.575038   41   two-sided  2.144895e-30  [-0.85, -0.74]  6.740528
#
#              BF10  power
# T-test  1.092e+27    1.0

# %% [markdown]
# ## VAS

# %%
VAS = sample[['VAS_preop', 'VAS_1mo', 'VAS_3mo', 'VAS_6mo',
       'VAS_12mo', 'VAS_24mo']]
VAS.head()
# Out:
#    VAS_preop  VAS_1mo  VAS_3mo  VAS_6mo  VAS_12mo  VAS_24mo
# 0          8        8        6        4         3         5
# 1          8        7        8        6         2         3
# 2         10        9        8        6         4         3
# 3          9        7        7        6         5         3
# 4          9        8        7        6         5         5

# %%
time_points = ['1mo', '3mo', '6mo', '12mo', '24mo']


for tp in time_points:
    followup_col = f"VAS_{tp}"  # Follow-up column name
        
    # Calculate the mean difference and its SD
    differences = VAS['VAS_preop'] - VAS[followup_col]
    mean_diff = np.mean(differences)
    sd_diff = np.std(differences, ddof=1)  # Use ddof=1 for sample SD
        
    # Perform the paired t-test
    result = pg.ttest(VAS['VAS_preop'], VAS[followup_col], paired=True, alternative='two-sided')
        
    # Print the result
    print(f"VAS: Preoperative vs {tp}")
    print(f"Mean Difference: {mean_diff:.2f} ± {sd_diff:.2f}")
    print(result)
    print("\n")
# Out:
# VAS: Preoperative vs 1mo
# Mean Difference: 0.26 ± 1.13
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test  1.505434   41   two-sided  0.139878  [-0.09, 0.61]  0.281699  0.473
#
#            power
# T-test  0.429793
#
#
# VAS: Preoperative vs 3mo
# Mean Difference: 1.57 ± 1.33
#                T  dof alternative         p-val         CI95%   cohen-d  \
# T-test  7.669817   41   two-sided  1.898962e-09  [1.16, 1.99]  1.602921
#
#              BF10  power
# T-test  6.176e+06    1.0
#
#
# VAS: Preoperative vs 6mo
# Mean Difference: 3.67 ± 1.12
#                 T  dof alternative         p-val         CI95%   cohen-d  \
# T-test  21.236761   41   two-sided  9.719980e-24  [3.32, 4.02]  3.434218
#
#              BF10  power
# T-test  3.663e+20    1.0
#
#
# VAS: Preoperative vs 12mo
# Mean Difference: 5.19 ± 1.69
#                 T  dof alternative         p-val         CI95%   cohen-d  \
# T-test  19.957457   41   two-sided  9.967922e-23  [4.67, 5.72]  4.641964
#
#              BF10  power
# T-test  3.821e+19    1.0
#
#
# VAS: Preoperative vs 24mo
# Mean Difference: 5.12 ± 1.47
#                 T  dof alternative         p-val         CI95%   cohen-d  \
# T-test  22.592688   41   two-sided  9.340984e-25  [4.66, 5.58]  4.641577
#
#              BF10  power
# T-test  3.567e+21    1.0

# %% [markdown]
# ## ODI

# %%
ODI = sample[['ODI_preop', 'ODI_1mo', 'ODI_3mo', 'ODI_6mo',
       'ODI_12mo', 'ODI_24mo']]
ODI.head()
# Out:
#    ODI_preop  ODI_1mo  ODI_3mo  ODI_6mo  ODI_12mo  ODI_24mo
# 0       0.88     0.80     0.72     0.60      0.38      0.40
# 1       0.84     0.78     0.78     0.58      0.40      0.38
# 2       0.74     0.80     0.74     0.56      0.44      0.30
# 3       0.80     0.80     0.78     0.54      0.40      0.48
# 4       0.74     0.84     0.78     0.58      0.40      0.34

# %%
time_points = ['1mo', '3mo', '6mo', '12mo', '24mo']


for tp in time_points:
    followup_col = f"ODI_{tp}"  # Follow-up column name
        
    # Calculate the mean difference and its SD
    differences = ODI['ODI_preop'] - ODI[followup_col]
    mean_diff = np.mean(differences)
    sd_diff = np.std(differences, ddof=1)  # Use ddof=1 for sample SD
        
    # Perform the paired t-test
    result = pg.ttest(ODI['ODI_preop'], ODI[followup_col], paired=True, alternative='two-sided')
        
    # Print the result
    print(f"ODI: Preoperative vs {tp}")
    print(f"Mean Difference: {mean_diff:.2f} ± {sd_diff:.2f}")
    print(result)
    print("\n")
# Out:
# ODI: Preoperative vs 1mo
# Mean Difference: 0.00 ± 0.07
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test  0.127697   41   two-sided  0.899013  [-0.02, 0.02]  0.028248  0.168
#
#            power
# T-test  0.053671
#
#
# ODI: Preoperative vs 3mo
# Mean Difference: 0.02 ± 0.07
#                T  dof alternative     p-val         CI95%  cohen-d   BF10  \
# T-test  1.704261   41   two-sided  0.095901  [-0.0, 0.04]  0.39577  0.628
#
#            power
# T-test  0.706942
#
#
# ODI: Preoperative vs 6mo
# Mean Difference: 0.21 ± 0.07
#                 T  dof alternative         p-val         CI95%   cohen-d  \
# T-test  19.244791   41   two-sided  3.846462e-22  [0.19, 0.24]  4.196205
#
#             BF10  power
# T-test  1.03e+19    1.0
#
#
# ODI: Preoperative vs 12mo
# Mean Difference: 0.41 ± 0.08
#                 T  dof alternative         p-val         CI95%   cohen-d  \
# T-test  34.698362   41   two-sided  5.141563e-32  [0.38, 0.43]  8.397093
#
#              BF10  power
# T-test  4.131e+28    1.0
#
#
# ODI: Preoperative vs 24mo
# Mean Difference: 0.41 ± 0.08
#                 T  dof alternative         p-val         CI95%   cohen-d  \
# T-test  32.104732   41   two-sided  1.112815e-30  [0.38, 0.44]  7.220843
#
#              BF10  power
# T-test  2.068e+27    1.0
